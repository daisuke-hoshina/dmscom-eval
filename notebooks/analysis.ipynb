# %% [markdown]
# # DMSCOM Metric Exploration
#
# This notebook is a lightweight template for inspecting DMSCOM results.
# Populate the `metrics/results.csv` file via `python scripts/batch_eval.py`, then run the cells below to load the data, run PCA, and visualize distributions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

df = pd.read_csv('metrics/results.csv')
df.head()

# %%
feature_cols = ['depth', 'fragment_imbalance', 'singleton_fragmentation']
X = df[feature_cols].fillna(0)
X_scaled = StandardScaler().fit_transform(X)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(6, 5))
plt.scatter(X_pca[:,0], X_pca[:,1])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA of DMSCOM metrics')
plt.show()
